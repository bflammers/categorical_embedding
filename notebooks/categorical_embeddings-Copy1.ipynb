# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx

# %%
import sys 
import os

parent_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if parent_path not in sys.path:
    sys.path.insert(1, parent_path)
    
# from src.fake_data import PSP
from src.categorical import CategoricalEmbedding, PCA, flip_signs, BlackSwanDetector

# %% [markdown]
# ### Functions for plotting

# %%
def rand_jitter(arr):
    stdev = max(0.001, .01*(max(arr)-min(arr)))
    return arr + np.random.randn(len(arr)) * stdev

def scatter_plot(x, y, col, jitter=True):
    
    if jitter:
        x = rand_jitter(x)
        y = rand_jitter(y)
    
    uniq = list(set(col))

    # Set the color map to match the number of species
    hot = plt.get_cmap('hot')
    cNorm  = colors.Normalize(vmin=0, vmax=len(uniq))
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=hot)

    for i, cat in enumerate(uniq):

        idx = col == cat

        plt.scatter(x[idx], y[idx], 
                    color=scalarMap.to_rgba(i), 
                    label=cat)
        
    # plt.legend(loc='upper left')
    # Put a legend to the right of the current axis
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

# %%
def generate_tx(anomaly_fields=None):
    
    tx = {
        'method': np.random.choice(['iDeal', 'bank_transfer', 'credit_card'], p=[0.4, 0.3, 0.3]),
        'sender_country': np.random.choice(['NL', 'DE', 'US'], p=[0.8, 0.15, 0.05]),
        'receiver_country': np.random.choice(['NL', 'DE', 'US'], p=[0.8, 0.15, 0.05]),
        'currency': np.random.choice(['EUR', 'USD', 'GBP'], p=[0.33, 0.33, 0.34]), 
        'class': 'normal'
    }
    
    if anomaly_fields:
        
        tx['class'] = 'anomaly'
        
        if 'method' in anomaly_fields:
            tx['method'] = np.random.choice(['iDeal', 'klarna', 'mr_cash'], p=[0.6, 0.2, 0.2])
            
        if 'sender_country' in anomaly_fields:
            tx['sender_country'] = np.random.choice(['GI', 'AF'], p=[0.7, 0.3])
            
        if 'receiver_country' in anomaly_fields:
            tx['receiver_country'] = np.random.choice(['GI', 'AF'], p=[0.5, 0.5])
            
        if 'currency' in anomaly_fields:
            tx['currency'] = np.random.choice(['AFN', 'DZD'], p=[0.5, 0.5])
        
    return tx

fields = ['method', 'sender_country', 'receiver_country', 'currency']

# %%
n = 500
p = 0.1

rows = []

for _ in range(n): 
    
    anomaly_fields = []
    while np.random.choice([True, False], p=[p, 1-p]):
        anomaly_fields.append(np.random.choice(fields))
        
    tx = generate_tx(anomaly_fields)
    rows.append(tx)
    
df = pd.DataFrame(rows)

# %%
df_cat = df.drop(columns='class')
df_dum = pd.get_dummies(df_cat)

# %%
df_dum.shape
# Out:
# (500, 20)

# %%
np.diag(np.cov(pcs.T)) > 1e-18
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
for col in df_dum:
    print(df_dum[col].value_counts())
# Out:
# 0    354
# 1    146
# Name: method_bank_transfer, dtype: int64
# 0    365
# 1    135
# Name: method_credit_card, dtype: int64
# 0    290
# 1    210
# Name: method_iDeal, dtype: int64
# 0    493
# 1      7
# Name: method_klarna, dtype: int64
# 0    498
# 1      2
# Name: method_mr_cash, dtype: int64
# 0    493
# 1      7
# Name: sender_country_AF, dtype: int64
# 0    426
# 1     74
# Name: sender_country_DE, dtype: int64
# 0    490
# 1     10
# Name: sender_country_GI, dtype: int64
# 1    377
# 0    123
# Name: sender_country_NL, dtype: int64
# 0    468
# 1     32
# Name: sender_country_US, dtype: int64
# 0    492
# 1      8
# Name: receiver_country_AF, dtype: int64
# 0    434
# 1     66
# Name: receiver_country_DE, dtype: int64
# 0    494
# 1      6
# Name: receiver_country_GI, dtype: int64
# 1    394
# 0    106
# Name: receiver_country_NL, dtype: int64
# 0    474
# 1     26
# Name: receiver_country_US, dtype: int64
# 0    494
# 1      6
# Name: currency_AFN, dtype: int64
# 0    489
# 1     11
# Name: currency_DZD, dtype: int64
# 0    345
# 1    155
# Name: currency_EUR, dtype: int64
# 0    316
# 1    184
# Name: currency_GBP, dtype: int64
# 0    356
# 1    144
# Name: currency_USD, dtype: int64

# %%
sppca = CategoricalEmbedding(drop_zero_variance=False)
bsd = BlackSwanDetector()

df_dum, df_dum_bs = bsd.fit_transform(df_dum)
pcs = sppca.fit_transform(df_dum)

# %%
pd.DataFrame(np.abs(sppca._eig_vecs)).style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
#     #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col0 {
#             background-color:  #3f4889;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col1 {
#             background-color:  #3f4889;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col2 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col4 {
#             background-color:  #2f6b8e;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col5 {
#             background-color:  #453781;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col6 {
#             background-color:  #481668;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col7 {
#             background-color:  #463480;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col8 {
#             background-color:  #481467;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col9 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col10 {
#             background-color:  #472e7c;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col11 {
#             background-color:  #22a884;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col12 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col13 {
#             background-color:  #460a5d;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col14 {
#             background-color:  #453882;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col15 {
#             background-color:  #1fa188;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col16 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col17 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col18 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row0_col19 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col0 {
#             background-color:  #3f4889;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col1 {
#             background-color:  #414287;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col2 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col3 {
#             background-color:  #471164;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col4 {
#             background-color:  #2c728e;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col5 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col6 {
#             background-color:  #481c6e;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col7 {
#             background-color:  #482576;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col8 {
#             background-color:  #460b5e;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col9 {
#             background-color:  #471063;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col10 {
#             background-color:  #3e4a89;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col11 {
#             background-color:  #6ccd5a;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col12 {
#             background-color:  #e7e419;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col13 {
#             background-color:  #481b6d;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col14 {
#             background-color:  #424086;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col15 {
#             background-color:  #277f8e;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col16 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col17 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col18 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row1_col19 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col0 {
#             background-color:  #3f4788;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col1 {
#             background-color:  #404688;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col2 {
#             background-color:  #470e61;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col3 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col4 {
#             background-color:  #2f6b8e;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col5 {
#             background-color:  #433d84;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col6 {
#             background-color:  #481b6d;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col7 {
#             background-color:  #481c6e;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col8 {
#             background-color:  #470e61;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col9 {
#             background-color:  #481a6c;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col10 {
#             background-color:  #482878;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col11 {
#             background-color:  #404688;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col12 {
#             background-color:  #481668;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col13 {
#             background-color:  #481d6f;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col14 {
#             background-color:  #470e61;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col15 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col16 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col17 {
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col18 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0aad473c_81b6_11ea_84f9_38f9d3622619row2_col19 {
#             background-color:  #fde725;

# %%
np.diag(np.cov(pcs.T)) > 1e-18
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#        False, False])

# %%
scatter_plot(x = pcs.iloc[:,0], 
             y = pcs.iloc[:,1],
             col = df['class'], 
             jitter=False)

# %%
n = 1000

x = np.random.binomial(1, 0.001, size = n)
df = pd.DataFrame({
    'a': np.random.binomial(1, 0.5, size = n),
    'b': np.random.binomial(1, 0.3, size = n),
    'c': np.random.binomial(1, 0.1, size = n) + x,
    'd': np.random.binomial(1, 0.01, size = n) + x,
    'e': np.random.binomial(1, 0.001, size = n)
})

# %%
sppca = CategoricalEmbedding(drop_zero_variance=False)
#bsd = BlackSwanDetector()

#df_dum, df_dum_bs = bsd.fit_transform(df)
pcs = sppca.fit_transform(df)
# Out:
# [[ 4.01346256e+00  2.12421196e-02 -1.07101518e-01  6.46890247e-01
#   -2.00871760e+00]
#  [ 2.12421196e-02  5.01067213e+00  2.91383633e-01  3.43556799e-03
#   -1.24787219e+00]
#  [-1.07101518e-01  2.91383633e-01  9.89882222e+00 -1.54617147e+00
#   -3.85248516e+00]
#  [ 6.46890247e-01  3.43556799e-03 -1.54617147e+00  6.79571632e+01
#    1.28587473e+00]
#  [-2.00871760e+00 -1.24787219e+00 -3.85248516e+00  1.28587473e+00
#    5.03315103e+02]]

# %%
scatter_plot(x = pcs.iloc[:,0], 
             y = pcs.iloc[:,1],
             col = df['c'], 
             jitter=True)

# %%
positive_counts = df_dum.apply(lambda x: sum(x))
positive_counts.sort_values()
# Out:
# method_mr_cash            1
# sender_country_AF         1
# currency_DZD              3
# method_klarna             3
# receiver_country_AF       6
# currency_AFN              8
# sender_country_GI         9
# receiver_country_US      12
# receiver_country_GI      12
# sender_country_US        33
# sender_country_DE        83
# receiver_country_DE      86
# method_bank_transfer    135
# currency_GBP            144
# currency_EUR            156
# method_credit_card      162
# currency_USD            189
# method_iDeal            199
# sender_country_NL       374
# receiver_country_NL     384
# dtype: int64

# %% [markdown]
# ### Experiment 2: what dimensions are captured without any anomalies?

# %% [markdown]
# Hypothesis: the dimensions with the smallest variance --> very unbalanced classes
#
# * method: balanced
# * sender_country: unbalanced --> US smallest category
# * receiver_country: unbalanced --> US smallest category
# * currency: balanced

# %%
n = 500

rows = []

for _ in range(n): 
    
    anomaly_fields = []        
    tx = generate_tx(anomaly_fields)
    rows.append(tx)
    
df_clean = pd.DataFrame(rows)

# %%
df_cat_clean = df_clean.drop(columns='class')
df_dum_clean = pd.get_dummies(df_cat_clean)

# %%
sppca_clean = CategoricalEmbedding()
pcs_clean = sppca_clean.fit_transform(df_dum_clean)

# %%
# Calculate components
components = super().transform(X, None)

# %%
# Which components have a variance larger than the threshold
components_mask = np.diag(np.cov(components.T)) > 1e-18

# %% [markdown]
# Focus is indeed on the US

# %%
scatter_plot(x = pcs_clean[:,0], 
             y = pcs_clean[:,1], 
             col = df_clean['receiver_country'], jitter=False)

# %% [markdown]
# ### Experiment 3: what happens when a category is not present in train set?

# %% [markdown]
# Hypothesis: if a category is not present in the training set the sspca will not focus on this dimension

# %%
n = 500

rows = []

for _ in range(n): 
    
    anomaly_fields = []        
    tx = generate_tx(anomaly_fields)
    rows.append(tx)
    
df_clean = pd.DataFrame(rows)

# %%
df_cat_clean = df_clean.drop(columns='class')
df_dum_clean = pd.get_dummies(df_cat_clean)
df_dum_clean['black_swan'] = 0

# %%
sppca_clean = SparsityPreservingPCA(black_swan_protection=False)
pcs_clean = sppca_clean.fit_transform(df_dum_clean)
pcs_clean.shape

# %%
scatter_plot(x = pcs_clean[:,0], 
             y = pcs_clean[:,1], 
             col = df_dum_clean['black_swan'])

# %%
df_dum_contam = df_dum_clean.copy()
df_dum_contam.loc[0, 'black_swan']=1

# %%
pcs_contam = sppca_clean.transform(df_dum_contam)

# %% [markdown]
# The anomaly is indeed not distinguishable in the first pcs. Around PC10 the anomaly becomes visible.

# %%
scatter_plot(x = pcs_contam[:,0], 
             y = pcs_contam[:,1], 
             col = df_dum_contam['black_swan'])

# %% [markdown]
# ### Experiment 4: remedy for black swan events

# %% [markdown]
# Hypothesis: if we append a row with all zeros and a row with all ones to the dummie df, black swan events can be captured
#
# Implemented in SparsityPreservingPCA class --> argument black_swan_protection=True

# %%
n = 500

rows = []

for _ in range(n): 
    
    anomaly_fields = []        
    tx = generate_tx(anomaly_fields)
    rows.append(tx)
    
df_clean = pd.DataFrame(rows)

# %%
df_cat_clean = df_clean.drop(columns='class')
df_dum_clean = pd.get_dummies(df_cat_clean)
df_dum_clean['black_swan1'] = 0
df_dum_clean['black_swan2'] = 0

# %%
sppca_clean = SparsityPreservingPCA(black_swan_protection=True)
pcs_clean = sppca_clean.fit_transform(df_dum_clean)

# %%
scatter_plot(x = pcs_clean[:,0], 
             y = pcs_clean[:,1],
             col = df_clean['method'], jitter=False) #df_dum_clean['black_swan1'])

# %%
positive_counts = df_dum_clean.apply(lambda x: sum(x))
positive_counts.sort_values()

# %%
df_dum_contam = df_dum_clean.copy()
df_dum_contam.loc[0, 'black_swan1']=1
df_dum_contam.loc[0, 'black_swan2']=0

# %%
pcs_contam = sppca_clean.transform(df_dum_contam)

# %% [markdown]
# The anomaly is now detected in the dimensions, this is the black swan column

# %%
scatter_plot(x = pcs_contam[:,0], 
             y = pcs_contam[:,1], 
             col = df_dum_contam['black_swan1'])

# %%
scatter_plot(x = pcs_clean[:,2], 
             y = pcs_clean[:,1], 
             col = df_clean['receiver_country'])
